# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehadi2012/Data-Science-in-Practice/blob/main/Querying_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/Admission_Predict.csv', index_col = 0)
df.columns = [x.lower().strip() for x in df.columns]
df
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1                 337          118  ...         1             0.92
# 2                 324          107  ...         1             0.76
# 3                 316          104  ...         1             0.72
# 4                 322          110  ...         1             0.80
# 5                 314          103  ...         0             0.65
# ...               ...          ...  ...       ...              ...
# 396               324          110  ...         1             0.82
# 397               325          107  ...         1             0.84
# 398               330          116  ...         1             0.91
# 399               312          103  ...         0             0.67
# 400               333          117  ...         1             0.95
#
# [400 rows x 8 columns]

# %%
admit_mask = df['chance of admit'] > 0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1               337.0        118.0  ...       1.0             0.92
# 2               324.0        107.0  ...       1.0             0.76
# 3               316.0        104.0  ...       1.0             0.72
# 4               322.0        110.0  ...       1.0             0.80
# 5                 NaN          NaN  ...       NaN              NaN
#
# [5 rows x 8 columns]

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1               337.0        118.0  ...       1.0             0.92
# 2               324.0        107.0  ...       1.0             0.76
# 3               316.0        104.0  ...       1.0             0.72
# 4               322.0        110.0  ...       1.0             0.80
# 6               330.0        115.0  ...       1.0             0.90
#
# [5 rows x 8 columns]

# %%
df[df['chance of admit'] > 0.7].head()       # a shorthand syntax which combines where() and dropna() doing both at once
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1                 337          118  ...         1             0.92
# 2                 324          107  ...         1             0.76
# 3                 316          104  ...         1             0.72
# 4                 322          110  ...         1             0.80
# 6                 330          115  ...         1             0.90
#
# [5 rows x 8 columns]

# %%
df['sop'].head()
# Out:
# Serial No.
# 1    4.5
# 2    4.0
# 3    3.0
# 4    3.5
# 5    2.0
# Name: sop, dtype: float64

# %%
df[['gre score','toefl score']].head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
df[df['gre score'] > 333].head()
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1                 337          118  ...         1             0.92
# 24                334          119  ...         1             0.95
# 25                336          119  ...         1             0.97
# 26                340          120  ...         1             0.94
# 33                338          118  ...         1             0.91
#
# [5 rows x 8 columns]

# %%
(df['chance of admit']> 0.7) & (df['chance of admit'] < 0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7) & df['chance of admit'].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool
