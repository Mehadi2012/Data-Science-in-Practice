# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehadi2012/Data-Science-in-Practice/blob/main/DataFrame2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df= pd.read_csv('/content/sample_data/Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1              0.92
# 1           2        324          107  ...  8.87         1              0.76
# 2           3        316          104  ...  8.00         1              0.72
# 3           4        322          110  ...  8.67         1              0.80
# 4           5        314          103  ...  8.21         0              0.65
#
# [5 rows x 9 columns]

# %%
df = pd.read_csv('/content/sample_data/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  ...  Research  Chance of Admit
# Serial No.                          ...
# 1                 337          118  ...         1              0.92
# 2                 324          107  ...         1              0.76
# 3                 316          104  ...         1              0.72
# 4                 322          110  ...         1              0.80
# 5                 314          103  ...         0              0.65
#
# [5 rows x 8 columns]

# %%
new_df = df.rename(columns={'GRE Score':'GRE Score', 'TOEFL Score':'TOEFL Score',
                            'University Rating':'University Rating',
                            'SOP':'Statement of Purpose','LOR':'Letter of Recommendation','CGPA':'CGPA',
                            'Research':'Research','Chance of Admit':'Chance of Admit'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  ...  Research  Chance of Admit
# Serial No.                          ...
# 1                 337          118  ...         1              0.92
# 2                 324          107  ...         1              0.76
# 3                 316          104  ...         1              0.72
# 4                 322          110  ...         1              0.80
# 5                 314          103  ...         0              0.65
#
# [5 rows x 8 columns]

# %%
new_df.columns    # a space is there in the end of the LOR and that is why it didn't change
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = new_df.rename(columns={"LOR ":"Letter of Recommendation"})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  ...  Research  Chance of Admit
# Serial No.                          ...
# 1                 337          118  ...         1              0.92
# 2                 324          107  ...         1              0.76
# 3                 316          104  ...         1              0.72
# 4                 322          110  ...         1              0.80
# 5                 314          103  ...         0              0.65
#
# [5 rows x 8 columns]

# %%
new_df = new_df.rename(mapper = str.strip, axis = 'columns')
new_df.head()
# Out:
#             GRE Score  TOEFL Score  ...  Research  Chance of Admit
# Serial No.                          ...
# 1                 337          118  ...         1             0.92
# 2                 324          107  ...         1             0.76
# 3                 316          104  ...         1             0.72
# 4                 322          110  ...         1             0.80
# 5                 314          103  ...         0             0.65
#
# [5 rows x 8 columns]

# %%
df.columns  # so rename function isn't modifying the dataframe. there is just a copy in new_df with the changed names
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
cols = list(df.columns)
cols = [x.lower().strip()for x in cols]

df.columns = cols 
df.head()
# Out:
#             gre score  toefl score  ...  research  chance of admit
# Serial No.                          ...
# 1                 337          118  ...         1             0.92
# 2                 324          107  ...         1             0.76
# 3                 316          104  ...         1             0.72
# 4                 322          110  ...         1             0.80
# 5                 314          103  ...         0             0.65
#
# [5 rows x 8 columns]
