# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehadi2012/Data-Science-in-Practice/blob/main/pandas_idioms_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import timeit

df = pd.read_csv('/content/sample_data/census.csv', encoding= 'latin-1')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 0      40       3         6  ...     1.383282     1.724718    0.712594
# 1      50       3         6  ...    -2.722002     2.592270   -2.187333
# 2      50       3         6  ...    22.727626    20.317142   18.293499
# 3      50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4      50       3         6  ...    -5.403729     0.754533    1.107861
#
# [5 rows x 100 columns]

# %%
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010':'Estimate Base 2010'}))
# Out:
#                           SUMLEV  REGION  ...  RNETMIG2014  RNETMIG2015
# STNAME   CTYNAME                          ...
# Alabama  Autauga County     50.0     3.0  ...     2.592270    -2.187333
#          Baldwin County     50.0     3.0  ...    20.317142    18.293499
#          Barbour County     50.0     3.0  ...    -3.978583   -10.543299
#          Bibb County        50.0     3.0  ...     0.754533     1.107861
#          Blount County      50.0     3.0  ...    -1.577232    -0.884411
# ...                          ...     ...  ...          ...          ...
# Missouri DeKalb County      50.0     2.0  ...    -4.718279     0.472981
#          Dent County        50.0     2.0  ...    -6.651956     2.053190
#          Douglas County     50.0     2.0  ...     8.814488   -13.448750
#          Dunklin County     50.0     2.0  ...   -11.993908   -13.879295
#          Franklin County    50.0     2.0  ...     0.137431     0.704415
#
# [1519 rows x 98 columns]

# %%
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace = True)
df.rename(columns={'ESTIMATEBASE2010':'Estimate Base 2010'})
# Out:
#                           SUMLEV  REGION  ...  RNETMIG2014  RNETMIG2015
# STNAME   CTYNAME                          ...
# Alabama  Autauga County       50       3  ...     2.592270    -2.187333
#          Baldwin County       50       3  ...    20.317142    18.293499
#          Barbour County       50       3  ...    -3.978583   -10.543299
#          Bibb County          50       3  ...     0.754533     1.107861
#          Blount County        50       3  ...    -1.577232    -0.884411
# ...                          ...     ...  ...          ...          ...
# Missouri Dent County          50       2  ...    -6.651956     2.053190
#          Douglas County       50       2  ...     8.814488   -13.448750
#          Dunklin County       50       2  ...   -11.993908   -13.879295
#          Franklin County      50       2  ...     0.137431     0.704415
# Misso    NaN                  50       2  ...          NaN          NaN
#
# [1520 rows x 98 columns]

# %%
def first_approach():
  global df
  return (df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010':'Estimate Base 2010'}))
  
df = pd.read_csv('/content/sample_data/census.csv', encoding= 'latin-1')
timeit.timeit(first_approach, number = 10)
# Out:
# 0.26991492600001266

# %%
def second_approach():
  global df
  new_df = df[df['SUMLEV']==50]
  new_df.set_index(['STNAME','CTYNAME'], inplace = True)
  return new_df.rename(columns={'ESTIMATEBASE2010':'Estimate Base 2010'})

df = pd.read_csv('/content/sample_data/census.csv', encoding= 'latin-1')
timeit.timeit(second_approach, number = 10)
# Out:
# 0.06893299399999364

# %%
def min_max(row):
  data = row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
  return pd.Series({'min':np.min(data), 'max':np.max(data)})

# %%
df.apply(min_max, axis='columns').head()
# Out:
#        min      max
# 0  4785161  4858979
# 1    54660    55347
# 2   183193   203709
# 3    26489    27341
# 4    22512    22861

# %%
def min_max(row):
  data = row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
  row['max'] = np.max(data)
  row['min'] = np.min(data)
  return row


df.apply(min_max, axis = 'columns')
# Out:
#       SUMLEV  REGION  DIVISION  ...  RNETMIG2015      max      min
# 0         40       3         6  ...     0.712594  4858979  4785161
# 1         50       3         6  ...    -2.187333    55347    54660
# 2         50       3         6  ...    18.293499   203709   183193
# 3         50       3         6  ...   -10.543299    27341    26489
# 4         50       3         6  ...     1.107861    22861    22512
# ...      ...     ...       ...  ...          ...      ...      ...
# 3188      50       4         8  ...   -14.070195    45162    43593
# 3189      50       4         8  ...     1.520747    23125    21297
# 3190      50       4         8  ...   -12.606351    21102    20822
# 3191      50       4         8  ...     1.441961     8545     8316
# 3192      50       4         8  ...     6.935294     7234     7065
#
# [3193 rows x 102 columns]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 0      40       3         6  ...     1.383282     1.724718    0.712594
# 1      50       3         6  ...    -2.722002     2.592270   -2.187333
# 2      50       3         6  ...    22.727626    20.317142   18.293499
# 3      50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4      50       3         6  ...    -5.403729     0.754533    1.107861
#
# [5 rows x 100 columns]

# %%
rows = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']
df.apply(lambda x:np.max(x[rows]), axis = 1).head()
# Out:
# 0    4858979
# 1      55347
# 2     203709
# 3      27341
# 4      22861
# dtype: int64

# %%
def get_state_region(x):
  northeast = ['Connecticut', 'Maine','Massachusetts','New Hampshire','Rhode Island','Vermont','New York','New Jersey','Pennysylvania']
  midwest = ['illinois', 'Indiana','Michigan','Ohio','Wisconsin','Iowa','Kansas','Minnesota','Missouri','Nebraska','North Dakota','South Dakota']
  south = ['Delaware', 'Florida','Georgia','Maryland','North Carolina','South Carolina','Virginia','District of Columbia','West Virginia','Alabama','Kentucky','Mississippi','Tennessee','Arkansas','Louisiana','Oklahoma','Texas']
  west = ['Arizona', 'Colorado','Idaho','Montana','Nevada','New Maxico','Utah','Wyoming','Alaska','California','Hawaii','Oregon','Washington']

  if x in northeast:
    return 'Northeast'
  elif x in midwest:
    return 'Midwest'
  elif x in south:
    return 'South'
  else:
    return 'West'

# %%
df['state_region']=df['STNAME'].apply(lambda x: get_state_region(x))

# %%
df[['STNAME','state_region']].head()
# Out:
#     STNAME state_region
# 0  Alabama        South
# 1  Alabama        South
# 2  Alabama        South
# 3  Alabama        South
# 4  Alabama        South
